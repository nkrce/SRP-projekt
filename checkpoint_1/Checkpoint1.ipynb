# %% [markdown]
# Anime Recommendation Database 2020

# %%
# Provjera da li je python instaliran na sustavu
print("Hello World")
# Out:
# Hello World

# %%
# Učitavanje potrebnih biblioteka
import pandas as pd

# Učitavanje podataka iz CSV datoteke
PATH = "/content/anime.csv"

# Učitavanje prvih 2000 redova
data = pd.read_csv(PATH, delimiter=',', nrows=2000)

# Ispis prvih 5 redova
print(data.head())
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
# 4                            冒険王ビィト     TV       52
#
#                           Aired    Premiered  ...  Score-10   Score-9  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998  ...  229170.0  182126.0
# 1                   Sep 1, 2001      Unknown  ...   30043.0   49201.0
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998  ...   50229.0   75651.0
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002  ...    2182.0    4806.0
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004  ...     312.0     529.0
#
#     Score-8  Score-7  Score-6 Score-5 Score-4  Score-3  Score-2  Score-1
# 0  131625.0  62330.0  20688.0  8904.0  3184.0   1357.0    741.0   1580.0
# 1   49505.0  22632.0   5805.0  1877.0   577.0    221.0    109.0    379.0
# 2   86142.0  49432.0  15376.0  5838.0  1965.0    664.0    316.0    533.0
# 3   10128.0  11618.0   5709.0  2920.0  1083.0    353.0    164.0    131.0
# 4    1242.0   1713.0   1068.0   634.0   265.0     83.0     50.0     27.0
#
# [5 rows x 35 columns]

# %%
# Ispis dimenzija skupa podataka (potrebno je učitati sve podatke radi analize, ne samo prvih 2000 redova)
data = pd.read_csv(PATH, delimiter=',')
print(data.shape)
# Out:
# (17562, 35)

# %%
# Ispis imena stupaca i nedostajućih vrijednosti
print(data.isna().sum())
# Out:
# MAL_ID           0
# Name             0
# Score            0
# Genres           0
# English name     0
# Japanese name    0
# Type             0
# Episodes         0
# Aired            0
# Premiered        0
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Duration         0
# Rating           0
# Ranked           0
# Popularity       0
# Members          0
# Favorites        0
# Watching         0
# Completed        0
# On-Hold          0
# Dropped          0
# Plan to Watch    0
# Score-10         0
# Score-9          0
# Score-8          0
# Score-7          0
# Score-6          0
# Score-5          0
# Score-4          0
# Score-3          0
# Score-2          0
# Score-1          0
# dtype: int64

# %%
# Ispis broja jedinstvenih vrijednosti po stupcima
print(data.nunique())
# Out:
# MAL_ID           17562
# Name             17558
# Score              533
# Genres            5034
# English name      6831
# Japanese name    16679
# Type                 7
# Episodes           201
# Aired            11947
# Premiered          231
# Producers         3783
# Licensors          231
# Studios           1090
# Source              16
# Duration           313
# Rating               7
# Ranked           10490
# Popularity       11755
# Members           9508
# Favorites         1543
# Watching          3580
# Completed         7822
# On-Hold           2915
# Dropped           3035
# Plan to Watch     7055
# Score-10          3379
# Score-9           3645
# Score-8           4515
# Score-7           4933
# Score-6           4236
# Score-5           3288
# Score-4           2235
# Score-3           1506
# Score-2           1110
# Score-1           1084
# dtype: int64

# %%
# Ispis tipova podataka po stupcima
print(data.dtypes)
# Out:
# MAL_ID            int64
# Name             object
# Score            object
# Genres           object
# English name     object
# Japanese name    object
# Type             object
# Episodes         object
# Aired            object
# Premiered        object
# Producers        object
# Licensors        object
# Studios          object
# Source           object
# Duration         object
# Rating           object
# Ranked           object
# Popularity        int64
# Members           int64
# Favorites         int64
# Watching          int64
# Completed         int64
# On-Hold           int64
# Dropped           int64
# Plan to Watch     int64
# Score-10         object
# Score-9          object
# Score-8          object
# Score-7          object
# Score-6          object
# Score-5          object
# Score-4          object
# Score-3          object
# Score-2          object
# Score-1          object
# dtype: object

# %%
# Ispis broja jedinstvenih vrijednosti po stupcima
for column in data:
    print(data[column].value_counts())
    input("...")
# Out:
# MAL_ID
# 48492    1
# 1        1
# 5        1
# 6        1
# 7        1
#         ..
# 24       1
# 23       1
# 22       1
# 21       1
# 20       1
# Name: count, Length: 17562, dtype: int64
# ...
# Name
# Maou Gakuin no Futekigousha: Shijou Saikyou no Maou no Shiso, Tensei shite Shison-tachi no Gakkou e    3
# Hinamatsuri                                                                                            2
# Youkoso! Ecolo Shima                                                                                   2
# Nijiiro Days: Houkago Special                                                                          1
# Shouwa Genroku Rakugo Shinjuu: Sukeroku Futatabi-hen                                                   1
#                                                                                                       ..
# Kakko Kawaii Sengen!                                                                                   1
# 30-sai no Hoken Taiiku                                                                                 1
# Asobi ni Iku yo!: Asobi ni Oide                                                                        1
# K-On! Movie                                                                                            1
# Goddamn                                                                                                1
# Name: count, Length: 17558, dtype: int64
# ...
# Score
# Unknown    5141
# 6.48         74
# 6.3          72
# 6.31         72
# 6.52         71
#            ...
# 2.18          1
# 8.88          1
# 9.17          1
# 3.89          1
# 4.06          1
# Name: count, Length: 533, dtype: int64
# ...
# Genres
# Hentai                                     969
# Music                                      790
# Comedy                                     668
# Kids                                       413
# Kids, Music                                234
#                                           ...
# Mystery, Comedy, Drama, Romance              1
# Game, Comedy, School, Seinen, Shoujo Ai      1
# Mystery, Supernatural, Shounen               1
# Action, Game, Comedy, Fantasy                1
# Music, Slice of Life, Kids, Shoujo           1
# Name: count, Length: 5034, dtype: int64
# ...
# English name
# Unknown                                      10565
# Cyborg 009                                       4
# Meow Meow Japanese History                       4
# Spirit Guardians                                 4
# Rakshasa Street                                  4
#                                              ...
# Return of Pero                                   1
# Samurai Harem                                    1
# Magical Girl Lyrical Nanoha:The Movie 1st        1
# Casshern Sins                                    1
# 8 Man                                            1
# Name: count, Length: 6831, dtype: int64
# ...
# Japanese name
# Unknown                     48
# ゲゲゲの鬼太郎                      6
# 僕のヒーローアカデミア                  5
# おしりたんてい                      4
# 宇宙の騎士テッカマンブレード               4
#                             ..
# 酎ハイれもんLOVE30S 雨にぬれても         1
# ONE PIECE 3D 麦わらチェイス         1
# エスパー魔美スペシャル マイエンジェル魔美ちゃん     1
# 駕籠真太郎アニメ作品集                  1
# 喜羊羊与灰太狼之虎虎生威                 1
# Name: count, Length: 16679, dtype: int64
# ...
# Type
# TV         4996
# OVA        3894
# Movie      3041
# Special    2218
# ONA        1907
# Music      1469
# Unknown      37
# Name: count, dtype: int64
# ...
# Episodes
# 1      8381
# 12     1445
# 2      1368
# 13      769
# 3       631
#        ...
# 744       1
# 146       1
# 122       1
# 135       1
# 160       1
# Name: count, Length: 201, dtype: int64
# ...
# Aired
# Unknown                         309
# 2005                             57
# 2004                             49
# 2003                             46
# 2021 to ?                        46
#                                ...
# Oct 3, 2002 to Feb 8, 2007        1
# Apr 7, 2004 to Sep 28, 2005       1
# Apr 17, 2004 to Feb 18, 2006      1
# Sep 11, 2002 to Sep 10, 2003      1
# Apr 15, 2005 to Sep 27, 2005      1
# Name: count, Length: 11947, dtype: int64
# ...
# Premiered
# Unknown        12817
# Spring 2017       86
# Fall 2016         79
# Spring 2018       77
# Spring 2016       74
#                ...
# Summer 1962        1
# Summer 1974        1
# Spring 1964        1
# Spring 1961        1
# Summer 1964        1
# Name: count, Length: 231, dtype: int64
# ...
# Producers
# Unknown                                                                                                                                               7794
# NHK                                                                                                                                                    623
# Pink Pineapple                                                                                                                                         184
# Sanrio                                                                                                                                                 160
# Bandai Visual                                                                                                                                          117
#                                                                                                                                                       ...
# Lantis, Media Factory, TBS, Sony Music Communications, Sakura Create                                                                                     1
# T-Rex, BOOTLEG                                                                                                                                           1
# TV Tokyo, Bandai Visual, TMS Entertainment, MediaNet, Kids Station, Movic, Cyclone Graphics, Tokyo Theatres, Sammy, Shogakukan, Imagine, TMS Music       1
# SBS TV Production                                                                                                                                        1
# d-rights, Tokuma Shoten                                                                                                                                  1
# Name: count, Length: 3783, dtype: int64
# ...
# Licensors
# Unknown                            13616
# Funimation                           883
# Sentai Filmworks                     652
# Media Blasters                       206
# Discotek Media                       194
#                                    ...
# Warner Bros. Japan, Crunchyroll        1
# Discotek Media, Ponycan USA            1
# Media Bank                             1
# Sentai Filmworks, Kadokawa             1
# iQIYI                                  1
# Name: count, Length: 231, dtype: int64
# ...
# Studios
# Unknown                            7079
# Toei Animation                      755
# Sunrise                             479
# J.C.Staff                           358
# Madhouse                            324
#                                    ...
# PONOS Corporation                     1
# ORENDA                                1
# OLM, P.I.C.S.                         1
# Yostar Pictures                       1
# Hai An Xian Donghua Gongzuo Shi       1
# Name: count, Length: 1090, dtype: int64
# ...
# Source
# Original         5215
# Manga            3825
# Unknown          3567
# Visual novel      993
# Game              880
# Light novel       768
# Other             597
# Novel             510
# Music             317
# 4-koma manga      288
# Web manga         252
# Picture book      147
# Book              112
# Card game          64
# Digital manga      15
# Radio              12
# Name: count, dtype: int64
# ...
# Duration
# 24 min. per ep.          1723
# 23 min. per ep.          1070
# 25 min. per ep.           846
# 30 min. per ep.           746
# 2 min.                    745
#                          ...
# 1 hr. 27 min. per ep.       1
# 48 sec.                     1
# 6 sec.                      1
# 43 sec.                     1
# 55 sec. per ep.             1
# Name: count, Length: 313, dtype: int64
# ...
# Rating
# PG-13 - Teens 13 or older         6132
# G - All Ages                      5782
# PG - Children                     1461
# Rx - Hentai                       1345
# R - 17+ (violence & profanity)    1157
# R+ - Mild Nudity                   997
# Unknown                            688
# Name: count, dtype: int64
# ...
# Ranked
# Unknown    1762
# 12978.0       6
# 5297.0        6
# 11806.0       5
# 14852.0       5
#            ...
# 2664.0        1
# 625.0         1
# 6493.0        1
# 675.0         1
# 30.0          1
# Name: count, Length: 10490, dtype: int64
# ...
# Popularity
# 4161     6
# 11039    6
# 7656     5
# 7944     5
# 13393    5
#         ..
# 12311    1
# 17560    1
# 17552    1
# 17156    1
# 14081    1
# Name: count, Length: 11755, dtype: int64
# ...
# Members
# 142      31
# 120      30
# 104      28
# 126      27
# 135      27
#          ..
# 20470     1
# 59440     1
# 1900      1
# 826       1
# 13734     1
# Name: count, Length: 9508, dtype: int64
# ...
# Favorites
# 0        5682
# 1        1806
# 2         950
# 3         674
# 4         512
#          ...
# 608         1
# 8762        1
# 7246        1
# 14335       1
# 2020        1
# Name: count, Length: 1543, dtype: int64
# ...
# Watching
# 6         448
# 7         406
# 9         373
# 8         359
# 0         357
#          ...
# 1101        1
# 245814      1
# 96190       1
# 7951        1
# 3539        1
# Name: count, Length: 3580, dtype: int64
# ...
# Completed
# 0         531
# 1          68
# 53         60
# 87         58
# 64         55
#          ...
# 3656        1
# 115230      1
# 46023       1
# 12453       1
# 134112      1
# Name: count, Length: 7822, dtype: int64
# ...
# On-Hold
# 0        871
# 2        741
# 1        681
# 3        642
# 4        628
#         ...
# 2508       1
# 13572      1
# 1537       1
# 9352       1
# 3532       1
# Name: count, Length: 2915, dtype: int64
# ...
# Dropped
# 0        376
# 35       202
# 36       192
# 34       190
# 38       184
#         ...
# 2186       1
# 8112       1
# 7951       1
# 13491      1
# 12516      1
# Name: count, Length: 3035, dtype: int64
# ...
# Plan to Watch
# 26       79
# 33       73
# 25       70
# 21       69
# 32       65
#          ..
# 2880      1
# 99988     1
# 24784     1
# 4302      1
# 3320      1
# Name: count, Length: 7055, dtype: int64
# ...
# Score-10
# 4.0        936
# 5.0        902
# 3.0        751
# 6.0        750
# 7.0        616
#           ...
# 4041.0       1
# 4347.0       1
# 1906.0       1
# 17409.0      1
# 5973.0       1
# Name: count, Length: 3379, dtype: int64
# ...
# Score-9
# Unknown    3167
# 1.0        1256
# 2.0         748
# 3.0         511
# 4.0         452
#            ...
# 1376.0        1
# 16711.0       1
# 22960.0       1
# 4236.0        1
# 1525.0        1
# Name: count, Length: 3645, dtype: int64
# ...
# Score-8
# Unknown    1371
# 1.0        1203
# 2.0         872
# 3.0         598
# 4.0         484
#            ...
# 1215.0        1
# 6932.0        1
# 56683.0       1
# 840.0         1
# 1263.0        1
# Name: count, Length: 4515, dtype: int64
# ...
# Score-7
# 2.0        610
# 1.0        607
# 3.0        546
# Unknown    503
# 4.0        448
#           ...
# 2343.0       1
# 6249.0       1
# 12702.0      1
# 27327.0      1
# 16284.0      1
# Name: count, Length: 4933, dtype: int64
# ...
# Score-6
# Unknown    511
# 2.0        416
# 3.0        408
# 4.0        386
# 5.0        363
#           ...
# 2051.0       1
# 1576.0       1
# 5181.0       1
# 8199.0       1
# 5056.0       1
# Name: count, Length: 4236, dtype: int64
# ...
# Score-5
# Unknown    584
# 6.0        310
# 5.0        302
# 7.0        292
# 4.0        280
#           ...
# 4381.0       1
# 3148.0       1
# 2621.0       1
# 5838.0       1
# 8904.0       1
# Name: count, Length: 3288, dtype: int64
# ...
# Score-4
# Unknown    977
# 1.0        621
# 2.0        564
# 4.0        478
# 3.0        471
#           ...
# 3350.0       1
# 961.0        1
# 3503.0       1
# 1204.0       1
# 1479.0       1
# Name: count, Length: 2235, dtype: int64
# ...
# Score-3
# Unknown    1307
# 1.0         966
# 2.0         778
# 3.0         639
# 4.0         573
#            ...
# 744.0         1
# 3421.0        1
# 780.0         1
# 3675.0        1
# 6098.0        1
# Name: count, Length: 1506, dtype: int64
# ...
# Score-2
# Unknown    1597
# 1.0        1109
# 2.0         911
# 3.0         867
# 4.0         702
#            ...
# 299.0         1
# 576.0         1
# 3350.0        1
# 747.0         1
# 2408.0        1
# Name: count, Length: 1110, dtype: int64
# ...
# Score-1
# 4.0       955
# 3.0       882
# 5.0       848
# 6.0       773
# 7.0       704
#          ...
# 610.0       1
# 840.0       1
# 3230.0      1
# 2070.0      1
# 597.0       1
# Name: count, Length: 1084, dtype: int64
# ...

# %%
# Ispis imena stupaca
print(data.columns.values)
# Out:
# ['MAL_ID' 'Name' 'Score' 'Genres' 'English name' 'Japanese name' 'Type'
#  'Episodes' 'Aired' 'Premiered' 'Producers' 'Licensors' 'Studios' 'Source'
#  'Duration' 'Rating' 'Ranked' 'Popularity' 'Members' 'Favorites'
#  'Watching' 'Completed' 'On-Hold' 'Dropped' 'Plan to Watch' 'Score-10'
#  'Score-9' 'Score-8' 'Score-7' 'Score-6' 'Score-5' 'Score-4' 'Score-3'
#  'Score-2' 'Score-1']
